# %%
import matplotlib.pyplot as plt
import modJoint as mj
import numpy as np

# %%
M = mj.modJoint()
M.run_model(1000)
# Out:
# 31.09555595257946
# Throwing away 247 trials with zero [0] spikes
# (array([121,  55, 169, 177,  53,   8, 134,   5,  46, 120, 155,  50, 168,
#         121,  97, 127, 106, 153, 155,  63,  28, 122, 121, 171,  82,  17,
#          82, 168,  69, 150,  36,   2, 170,  89,  57,  22, 108,  58, 146,
#          84,  51,  17,  19, 178, 102,  11, 105, 134,  21, 160,  33, 160,
#         119, 161,  60, 142,  18,  75, 128, 160,  49,  57, 160,  48, 110,
#          93, 104,  73,  56,   0,   1, 143,  17, 156,   8,  37, 172, 138,
#          84,  14, 171,  69, 167,  22,   9,  84, 124,   9,  77,  31, 140,
#         122, 127,  68,  32,  33, 167,  44,   8, 161,  38,  35, 128, 145,
#          70,  39, 104,  15,  62,  25,  54,  46,  57,  52, 161, 134, 138,
#          42, 111,  79, 109,  94, 179,   4,  33, 142, 109, 150, 169, 129,
#          26, 129, 100,  28,  81, 170,  93, 130, 105,   6,  58,  51, 119,
#          11,  92, 146,  68,  56,  11, 132, 111,  95,  30,  31,  14,   5,
# ...

# %%
theta = np.linspace(-pi,pi-(2*pi/self.n_view),180)
p_theta = 2 - np.abs(np.sin(theta))

# %%
?
